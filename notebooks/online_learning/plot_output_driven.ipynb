# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df_output = pd.read_csv('../../data/output/driven/testprofile_for_ol_trial_due/2024_08_07-14_06_07/dataset_0.csv')
df_output_ground_zero = pd.read_csv('../../data/output/driven/testprofile_for_ol_trial_due/2024_08_07-14_06_07/ground_0.csv')
df_ground = pd.read_csv('../../data/ground/single_current_cycle.csv')

# %%
df_ground.describe()
# Out:
#          Voltage(V)    Current(A)   Temperature      TempeAmb
# count  16314.000000  16314.000000  16314.000000  16314.000000
# mean      26.136937     -0.066348     29.154762     25.835638
# std        0.834090     19.343229      1.027736      0.424626
# min       24.478000    -32.551000     27.837000     24.848000
# 25%       25.496000    -16.209000     28.397000     25.564000
# 50%       26.055500     -1.041000     28.708000     25.782000
# 75%       26.692000     21.710000     29.673000     26.062000
# max       27.999000     23.953000     31.447000     27.494000

# %%
fig, ax = plt.subplots(figsize=(12,4))
ax.plot(df_ground['Voltage(V)'], label='ground')
ax.plot(df_output['voltage'], label='simulation')
ax.legend()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~/miniconda3/envs/dt-rse/lib/python3.8/site-packages/pandas/core/indexes/base.py:3361, in Index.get_loc(self, key, method, tolerance)
#    3360 try:
# -> 3361     return self._engine.get_loc(casted_key)
#    3362 except KeyError as err:
#
# File ~/miniconda3/envs/dt-rse/lib/python3.8/site-packages/pandas/_libs/index.pyx:76, in pandas._libs.index.IndexEngine.get_loc()
#
# File ~/miniconda3/envs/dt-rse/lib/python3.8/site-packages/pandas/_libs/index.pyx:108, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:5198, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:5206, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'voltage'
#
# The above exception was the direct cause of the following exception:
#
# ...

# %%
fig, ax = plt.subplots(figsize=(12,4))
ax.plot(df_ground['Current(A)'], label='ground')
ax.plot(df_output['current'], label='simulation')
ax.legend()
plt.show()

# %%
df_output.describe()
# Out:
#                time           soc           soh         c_max       voltage  \
# count  32620.000000  32620.000000  32620.000000  32620.000000  32620.000000
# mean   16627.797977      0.493468      0.999264     39.970563     26.402807
# std     9600.270353      0.173916      0.000505      0.020189      0.843326
# min        0.000000      0.161775      0.998118     39.924726     24.382026
# 25%     8313.750000      0.341999      0.998876     39.955055     25.810263
# 50%    16627.500000      0.497601      0.999320     39.972796     26.459606
# 75%    24941.250000      0.649195      0.999676     39.987047     27.063445
# max    33255.000000      0.799992      1.000000     40.000000     27.993067
#
#             current         power          v_oc            r0            r1  \
# count  32620.000000  32620.000000  32620.000000  32620.000000  32620.000000
# mean       0.067154      3.126303     26.436505      0.010238      0.018334
# ...

# %%
df_output['time'].plot()
# Out:
# <Axes: >
