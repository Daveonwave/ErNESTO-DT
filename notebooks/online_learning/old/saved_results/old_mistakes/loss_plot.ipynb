# %%
import pandas as pd
df_loss = pd.read_csv("history_loss.csv")

# %%
df_loss.describe()
# Out:
#        Unnamed: 0             0             1             2             3  \
# count  328.000000  3.280000e+02  3.280000e+02  3.280000e+02  3.280000e+02
# mean   163.500000  6.804267e+02  6.804267e+02  6.804268e+02  7.144450e+02
# std     94.829672  1.138605e-13  1.138605e-13  1.138605e-13  1.138605e-13
# min      0.000000  6.804267e+02  6.804267e+02  6.804268e+02  7.144450e+02
# 25%     81.750000  6.804267e+02  6.804267e+02  6.804268e+02  7.144450e+02
# 50%    163.500000  6.804267e+02  6.804267e+02  6.804268e+02  7.144450e+02
# 75%    245.250000  6.804267e+02  6.804267e+02  6.804268e+02  7.144450e+02
# max    327.000000  6.804267e+02  6.804267e+02  6.804268e+02  7.144450e+02
#
#                   4             5             6             7           8  \
# count  3.280000e+02  3.280000e+02  3.280000e+02  3.280000e+02  328.000000
# mean   6.464085e+02  6.123903e+02  6.350691e+02  6.048307e+02  567.032649
# std    1.138605e-13  1.138605e-13  1.138605e-13  1.138605e-13    0.000000
# ...

# %%
df_loss.plot()
# Out:
# <Axes: >
