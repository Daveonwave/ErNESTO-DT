# %%
import pandas as pd

# %%
df = pd.read_csv('saved_results/history_theta.csv')

# %%
df.describe()
# Out:
#        Unnamed: 0          r0          rc              c
# count  338.000000  338.000000  338.000000     338.000000
# mean   168.500000    0.002536    0.539710    5198.605113
# std     97.716426    0.021763    2.248752   21912.641482
# min      0.000000    0.001000    0.001000      10.000000
# 25%     84.250000    0.001000    0.001000      10.000000
# 50%    168.500000    0.001000    0.001000      10.000000
# 75%    252.750000    0.001000    0.001000      10.000000
# max    337.000000    0.399842   10.000000  100000.000000

# %%
df.drop(df.columns[0], axis=1)
# Out:
#            r0        rc           c
# 0    0.001000  0.270373  387.357706
# 1    0.399842  1.596592  496.836081
# 2    0.001000  0.001000   10.000000
# 3    0.001000  0.001000   10.000000
# 4    0.001000  0.001000   10.000000
# ..        ...       ...         ...
# 333  0.001000  0.001000   10.000000
# 334  0.001000  0.001000   10.000000
# 335  0.001000  0.001000   10.000000
# 336  0.001000  0.001000   10.000000
# 337  0.001000  0.001000   10.000000
#
# [338 rows x 3 columns]

# %%
theta_history = df.to_numpy()

# %%
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D

r0 = theta_history[:, 0]
rc = theta_history[:, 1]
c = theta_history[:, 2]

# Create a 3D plot
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')

# Plot the data points
ax.scatter(r0, rc, c)

# Set labels
ax.set_xlabel('r0 Label')
ax.set_ylabel('rc Label')
ax.set_zlabel('c Label')

# Show the plot
plt.show()

# %%
df_clusters = pd.read_csv("saved_results/nominal_clusters.csv")

# %%
df_clusters['cluster'][0]
# Out:
# '[array([1.00000000e-03, 3.72732184e-01, 1.00000000e+05]), array([3.56719718e-01, 4.97565397e-01, 7.07462070e+02]), array([  0.45009808,   4.65156923, 137.83017859]), array([1.e-03, 1.e-03, 1.e+01]), array([1.e-03, 1.e-03, 1.e+01]), array([1.e-03, 1.e-03, 1.e+01]), array([1.e-03, 1.e-03, 1.e+01]), array([1.e-03, 1.e-03, 1.e+01]), array([1.e-03, 1.e+01, 1.e+05]), array([1.e-03, 1.e-03, 1.e+05]), array([1.e-03, 1.e-03, 1.e+01]), array([1.e-03, 1.e-03, 1.e+01]), array([1.e-03, 1.e-03, 1.e+01]), array([1.e-03, 1.e-03, 1.e+01]), array([1.e-03, 1.e-03, 1.e+01]), array([1.e-03, 1.e-03, 1.e+01]), array([1.e-03, 1.e-03, 1.e+01]), array([1.e-03, 1.e-03, 1.e+01]), array([1.e-03, 1.e-03, 1.e+01]), array([1.e-03, 1.e-03, 1.e+01]), array([1.e-03, 1.e-03, 1.e+01]), array([1.e-03, 1.e-03, 1.e+01]), array([1.e-03, 1.e-03, 1.e+01]), array([1.e-03, 1.e+01, 1.e+05]), array([1.e-03, 1.e-03, 1.e+01]), array([1.e-03, 1.e-03, 1.e+01]), array([1.e-03, 1.e-03, 1.e+01]), array([1.e-03, 1.e-03, 1.e+05]), array(
# ...
