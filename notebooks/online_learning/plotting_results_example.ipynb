# %%
import pandas as pd
import numpy as np

df_voltage = pd.read_csv("voltage_final.csv")
df_ground = pd.read_csv("ground_20.csv")

# %%
df_voltage.plot()
# Out:
# <Axes: >

# %%
df_ground['voltage'].plot()
# Out:
# <Axes: >

# %%
df_voltage.describe()
# Out:
#             voltage  updated_voltage
# count  30001.000000     30001.000000
# mean       3.599801         3.929576
# std        0.158987         0.052049
# min        3.100793         3.760000
# 25%        3.500667         3.887544
# 50%        3.500667         3.922872
# 75%        3.730301         3.961737
# max        4.075045         4.071517

# %%
err = abs(df_voltage['voltage'] - df_ground['voltage'])
mse = np.mean(err**2)

# %%
df_err = pd.DataFrame(err)
df_err.plot()
# Out:
# <Axes: >

# %%
mse
# Out:
# 0.03921898355708685

# %% [markdown]
# ## Temperature Plot

# %%
df_temp = pd.read_csv("temp_final.csv")

# %%
df_temp.describe()
# Out:
#         temperature  updated_temp
# count  30001.000000  30001.000000
# mean     296.414079    295.157578
# std        1.266923      0.006325
# min      294.368494    295.150000
# 25%      295.336131    295.152906
# 50%      296.141278    295.155433
# 75%      296.970093    295.159966
# max      300.984894    295.173243

# %%
df_temp.plot()
# Out:
# <Axes: >

# %%
df_ground['temperature'].plot()
# Out:
# <Axes: >
