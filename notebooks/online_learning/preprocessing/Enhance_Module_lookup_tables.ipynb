# %% [markdown]
# ## MODULEDATA PREPARATION

# %% [markdown]
# This notebook is meant to take the RSE experiment results on battery module and enhance them with soh artificial measurements in order to simulate a slow drift signal(GROUND for the test)

# %%
import pandas as pd
import numpy as np
from src.online_learning.utils import utils
import os

# %% [markdown]
# # custom functions

# %%
def updateDf(df, listsToAdd, col ):
    tmp = []
    soh = [0.6, 0.7, 0.8, 0.9]
    for i in range(len(listsToAdd)):
        df_new = df.copy()
        df_new[col] = listsToAdd[i]
        df_new['Soh'] = soh[i]
        tmp.append(df_new)
    
    reversed_list_of_dfs = tmp[::-1]
    stacked_df = pd.concat([df] + reversed_list_of_dfs, axis=0).reset_index(drop=True) 
    
    return stacked_df

# %%
def enhanceParam(param_array, func):
    xp = np.array([0.6,1])
    x = np.array([0.7,0.8,0.9])
    lists = []
    
    for i in range(len(x)+2):
        lists.append(list)    
    
    lists[0] = func(param_array).tolist()
    lists[4] = param_array.tolist()
    
    tmp1 = []
    tmp2 = []
    tmp3 = []
    for elem in param_array:
        fp = np.array([func(elem),elem])
        y = np.interp(x,xp,fp)
        tmp1.append(y[0])
        tmp2.append(y[1])
        tmp3.append(y[2])    
    
    lists[1] = tmp1
    lists[2] = tmp2
    lists[3] = tmp3
       
    return lists

# %%
halve = lambda x: x/2
double = lambda x: x*2
one_third = lambda x:x/3

# %%
current_path = os.getcwd()
print("Current working directory:", current_path)
# Out:
# Current working directory: /mnt/c/Users/Nicola_Petkovic/Documents/dt-rse-davide/ErNESTO-DT/notebooks/online_learning/preprocessing

# %% [markdown]
# # Data Preparation

# %% [markdown]
# Currently working on 1exp experiment

# %%
relative_path_ground = os.path.join('..', '..','..', 'data', 'external', 'DT_CU1_parameters_1_exp.xlsx')
path_ground = utils.get_absolute_path(relative_path_ground)  
all_sheets = pd.read_excel(path_ground, sheet_name=None)

print(all_sheets.keys())
# Out:
# dict_keys(['T = 25', 'T = 10', 'T = 40'])

# %%
all_sheets['T = 25'].head(60)
# Out:
#                                              filename       data  \
# 0    20240514_20240515_concat_CU1_25C_3_Ciclatore.txt        NaT
# 1    20240514_20240515_concat_CU1_25C_3_Ciclatore.txt 2024-05-14
# 2    20240514_20240515_concat_CU1_25C_3_Ciclatore.txt 2024-05-14
# 3    20240514_20240515_concat_CU1_25C_3_Ciclatore.txt 2024-05-14
# 4    20240514_20240515_concat_CU1_25C_3_Ciclatore.txt 2024-05-14
# 5    20240514_20240515_concat_CU1_25C_3_Ciclatore.txt 2024-05-14
# 6    20240514_20240515_concat_CU1_25C_3_Ciclatore.txt 2024-05-14
# 7    20240514_20240515_concat_CU1_25C_3_Ciclatore.txt 2024-05-15
# 8    20240514_20240515_concat_CU1_25C_3_Ciclatore.txt 2024-05-15
# 9    20240514_20240515_concat_CU1_25C_3_Ciclatore.txt 2024-05-15
# 10   20240514_20240515_concat_CU1_25C_3_Ciclatore.txt 2024-05-15
# 11  20240524_20240525_20240526_concat_CU1_25C_4_Ci...        NaT
# 12  20240524_20240525_20240526_concat_CU1_25C_4_Ci... 2024-05-24
# 13  20240524_20240525_20240526_concat_CU1_25C_4_Ci... 2024-05-24
# 14  20240524_20240525_20240526_concat_CU1_25C_4_Ci... 2024-05-24
# 15  20240524_20240525_20240526_concat_CU1_25C_4_Ci... 2024-05-24
# 16  20240524_20240525_20240526_concat_CU1_25C_4_Ci... 2024-05-25
# 17  20240524_20240525_20240526_concat_CU1_25C_4_Ci... 2024-05-25
# 18  20240524_20240525_20240526_concat_CU1_25C_4_Ci... 2024-05-25
# 19  20240524_20240525_20240526_concat_CU1_25C_4_Ci... 2024-05-25
# 20  20240524_20240525_20240526_concat_CU1_25C_4_Ci... 2024-05-25
# 21  20240524_20240525_20240526_concat_CU1_25C_4_Ci... 2024-05-25
# 22  20240524_20240525_20240526_concat_CU1_25C_4_Ci...        NaT
# 23  20240524_20240525_20240526_concat_CU1_25C_4_Ci... 2024-05-25
# 24  20240524_20240525_20240526_concat_CU1_25C_4_Ci... 2024-05-25
# 25  20240524_20240525_20240526_concat_CU1_25C_4_Ci... 2024-05-25
# 26  20240524_20240525_20240526_concat_CU1_25C_4_Ci... 2024-05-26
# 27  20240524_20240525_20240526_concat_CU1_25C_4_Ci... 2024-05-26
# 28  20240524_20240525_20240526_concat_CU1_25C_4_Ci... 2024-05-26
# 29  20240524_20240525_20240526_concat_CU1_25C_4_Ci... 2024-05-26
# 30  20240524_20240525_20240526_concat_CU1_25C_4_Ci... 2024-05-26
# 31  20240524_20240525_20240526_concat_CU1_25C_4_Ci... 2024-05-26
# 32  20240524_20240525_20240526_concat_CU1_25C_4_Ci... 2024-05-26
# 33  20240529_20240530_20240531_concat_CU1_25C_5_Ci...        NaT
# 34  20240529_20240530_20240531_concat_CU1_25C_5_Ci... 2024-05-29
# 35  20240529_20240530_20240531_concat_CU1_25C_5_Ci... 2024-05-29
# 36  20240529_20240530_20240531_concat_CU1_25C_5_Ci... 2024-05-29
# 37  20240529_20240530_20240531_concat_CU1_25C_5_Ci... 2024-05-29
# 38  20240529_20240530_20240531_concat_CU1_25C_5_Ci... 2024-05-30
# 39  20240529_20240530_20240531_concat_CU1_25C_5_Ci... 2024-05-30
# 40  20240529_20240530_20240531_concat_CU1_25C_5_Ci... 2024-05-30
# 41  20240529_20240530_20240531_concat_CU1_25C_5_Ci... 2024-05-30
# 42  20240529_20240530_20240531_concat_CU1_25C_5_Ci... 2024-05-30
# 43  20240529_20240530_20240531_concat_CU1_25C_5_Ci... 2024-05-30
# 44  20240529_20240530_20240531_concat_CU1_25C_5_Ci...        NaT
# 45  20240529_20240530_20240531_concat_CU1_25C_5_Ci... 2024-05-30
# 46  20240529_20240530_20240531_concat_CU1_25C_5_Ci... 2024-05-30
# 47  20240529_20240530_20240531_concat_CU1_25C_5_Ci... 2024-05-30
# 48  20240529_20240530_20240531_concat_CU1_25C_5_Ci... 2024-05-31
# 49  20240529_20240530_20240531_concat_CU1_25C_5_Ci... 2024-05-31
# 50  20240529_20240530_20240531_concat_CU1_25C_5_Ci... 2024-05-31
# 51  20240529_20240530_20240531_concat_CU1_25C_5_Ci... 2024-05-31
# 52  20240529_20240530_20240531_concat_CU1_25C_5_Ci... 2024-05-31
# 53  20240529_20240530_20240531_concat_CU1_25C_5_Ci... 2024-05-31
# 54  20240529_20240530_20240531_concat_CU1_25C_5_Ci... 2024-05-31
#
#                             start interval  \
# 0   Not present - param from extrapolation
# 1                                 12:21:53
# 2                                 14:33:55
# 3                                 16:45:57
# 4                                 18:57:59
# 5                                 21:10:00
# 6                                 23:22:02
# 7                                 01:34:03
# 8                                 03:46:04
# 9                                 05:58:06
# 10                                08:10:08
# 11  Not present - param from extrapolation
# 12                                17:13:37
# 7   25.409000                                0.608851
# 8   25.057000                                0.352802
# 9   24.654000                               -0.069515
# 10  24.127000                                -0.28518
# 11  28.504571  Not present - param from extrapolation
# 12  28.259000                                0.117571
# 13  27.587000                                0.321027
# 14  26.997000                                 0.55843
# 15  26.322000                                0.216197
# 16  25.912000                                0.270945
# 17  25.659000                                0.513902
# 18  25.461000                                0.678138
# 19  25.150000                                0.294624
# 20  24.785000                               -0.070956
# 21  24.396000                                 0.07697
# 22  28.504429  Not present - param from extrapolation
# 23  28.259000                               -0.000809
# 24  27.587000                                0.264367
# 25  26.992000                                0.584164
# 26  26.314000                                0.244674
# 27  25.907000                                0.237723
# 28  25.654000                                0.560297
# 29  25.455000                                0.693371
# 30  25.135000                                0.333413
# 31  24.759000                                 0.02363
# 32  24.373000                               -0.040377
# 33  28.486286  Not present - param from extrapolation
# 34  28.243000                                0.577372
# 35  27.567000                                0.309727
# 36  26.958000                                 0.65623
# 37  26.268000                                0.214213
# 38  25.868000                                0.490088
# 39  25.623000                                0.634958
# 40  25.415000                                0.689759
# 41  25.056000                                0.583135
# 42  24.657000                                0.020003
# 43  24.114000                                0.188653
# 44  28.478714  Not present - param from extrapolation
# 45  28.242000                                0.342186
# 46  27.556000                                0.437702
# 47  26.941000                                0.703828
# 48  26.245000                                0.493961
# 49  25.859000                                0.456072
# 50  25.610000                                0.726517
# 51  25.401000                                0.716264
# 52  25.041000                                0.493204
# 53  24.615000                                0.214322
# 54  23.970000                                0.053308

# %%
all_sheets['T = 25'].describe()
# Out:
#               Soc   tau_guess  num value extrap        R_0        R_1  \
# count   55.000000    55.00000              55.0  55.000000  55.000000
# mean    50.000000  1655.86661               7.0   0.011520   0.015499
# std     31.914237     0.00000               0.0   0.002412   0.006471
# min      0.000000  1655.86661               7.0   0.009210   0.009238
# 25%     20.000000  1655.86661               7.0   0.010363   0.011560
# 50%     50.000000  1655.86661               7.0   0.010981   0.013876
# 75%     80.000000  1655.86661               7.0   0.011748   0.016568
# max    100.000000  1655.86661               7.0   0.022375   0.041071
#
#                 C_1        OCV
# count     55.000000  55.000000
# mean   11965.948149  26.224236
# std     3143.296922   1.375532
# min     4919.388300  23.970000
# 25%    10500.078051  25.142500
# 50%    11751.825878  25.868000
# 75%    13995.291319  27.550000
# max    19489.447086  28.504571

# %%
all_sheets['T = 25']['R_0'].plot()
# Out:
# <Axes: >

# %% [markdown]
# The graph shows that the same experiment is repeated multiple times, since it is relevant for the whatif simulation to have only one lookup, the average is performed.
# From the describe and head table can be seen that the experiments are repeated for 11 value of soc, hence the dataset is grouped by soc,i.e. 5 groups

# %%
R_0 = {}
R_1 = {}
C_1 = {}
for key,elem in all_sheets.items():
    R_0[key] = elem.groupby('Soc')['R_0'].mean()
    R_0[key] = R_0[key].reset_index()
    R_1[key] = elem.groupby('Soc')['R_1'].mean()
    R_1[key] = R_1[key].reset_index()
    C_1[key] = elem.groupby('Soc')['C_1'].mean()
    C_1[key] = C_1[key].reset_index()

# %% [markdown]
# After this at a given Soc will correspond the average value among the five lookup tables

# %%
R_0.keys()
# Out:
# dict_keys(['T = 25', 'T = 10', 'T = 40'])

# %% [markdown]
# Just check the results

# %%
R_0['T = 10'].head()
# Out:
#    Soc       R_0
# 0    0  0.029989
# 1   10  0.030855
# 2   20  0.022031
# 3   30  0.020390
# 4   40  0.019156

# %%
for key,elem in R_0.items():
    elem['Soh'] = 1

# %%
R_0['T = 25']['Temp'] = 25
R_0['T = 10']['Temp'] = 10
R_0['T = 40']['Temp'] = 40

# %%
R_0['T = 10'].head()
# Out:
#    Soc       R_0  Soh  Temp
# 0    0  0.029989    1    10
# 1   10  0.030855    1    10
# 2   20  0.022031    1    10
# 3   30  0.020390    1    10
# 4   40  0.019156    1    10

# %%
for key,elem in R_0.items():
    values = elem['R_0'].values
    values_enhanced = enhanceParam(values,double)
    tmp = updateDf(df=elem, listsToAdd=values_enhanced[0:3+1] ,col='R_0')
    R_0[key] = tmp

# %%
R_0['T = 10'].describe()
# Out:
#               Soc        R_0        Soh  Temp
# count   55.000000  55.000000  55.000000  55.0
# mean    50.000000   0.030465   0.800000  10.0
# std     31.914237   0.010810   0.142725   0.0
# min      0.000000   0.014912   0.600000  10.0
# 25%     20.000000   0.022284   0.700000  10.0
# 50%     50.000000   0.028982   0.800000  10.0
# 75%     80.000000   0.035601   0.900000  10.0
# max    100.000000   0.061709   1.000000  10.0

# %%
df_stacked_R0 = pd.concat(R_0)

# %%
df_stacked_R0.describe()
# Out:
#               Soc         R_0         Soh        Temp
# count  165.000000  165.000000  165.000000  165.000000
# mean    50.000000    0.019971    0.800000   25.000000
# std     31.719041    0.010515    0.141852   12.284732
# min      0.000000    0.007555    0.600000   10.000000
# 25%     20.000000    0.012349    0.700000   10.000000
# 50%     50.000000    0.016769    0.800000   25.000000
# 75%     80.000000    0.023945    0.900000   40.000000
# max    100.000000    0.061709    1.000000   40.000000

# %% [markdown]
# Repeated procedure for R1 and C1

# %%
R_1['T = 25']['Temp'] = 25
R_1['T = 10']['Temp'] = 10
R_1['T = 40']['Temp'] = 40

for key,elem in R_1.items():
    elem['Soh'] = 1
    
for key,elem in R_1.items():
    values = elem['R_1'].values
    values_enhanced = enhanceParam(values,double)
    tmp = updateDf(df=elem, listsToAdd=values_enhanced[0:3+1] ,col='R_1')
    R_1[key] = tmp 
df_stacked_R1 = pd.concat(R_1)

# %%
C_1['T = 25']['Temp'] = 25
C_1['T = 10']['Temp'] = 10
C_1['T = 40']['Temp'] = 40

for key,elem in C_1.items():
    elem['Soh'] = 1
    
for key,elem in C_1.items():
    values = elem['C_1'].values
    values_enhanced = enhanceParam(values,one_third)
    tmp = updateDf(df=elem, listsToAdd=values_enhanced[0:3+1] ,col='C_1')
    C_1[key] = tmp  
df_stacked_C1 = pd.concat(C_1)

# %%
df_stacked_C1.head()
# Out:
#           Soc           C_1  Temp  Soh
# T = 25 0    0   5811.382741    25  1.0
#        1   10  11404.450799    25  1.0
#        2   20  12600.929525    25  1.0
#        3   30  14661.237120    25  1.0
#        4   40  12066.767912    25  1.0

# %%
df_stacked_C1['C_1'].plot()
# Out:
# <Axes: >

# %%
df_stacked_C1.groupby(['Soh']).plot()
# Out:
# Soh
# 0.6    Axes(0.125,0.11;0.775x0.77)
# 0.7    Axes(0.125,0.11;0.775x0.77)
# 0.8    Axes(0.125,0.11;0.775x0.77)
# 0.9    Axes(0.125,0.11;0.775x0.77)
# 1.0    Axes(0.125,0.11;0.775x0.77)
# dtype: object

# %%
df_stacked_C1.to_csv('c1_module_enhanced_table.csv', index=False)
df_stacked_R1.to_csv('r1_module_enhanced_table.csv', index=False)
df_stacked_R0.to_csv('r0_module_enhanced_table.csv', index=False)
