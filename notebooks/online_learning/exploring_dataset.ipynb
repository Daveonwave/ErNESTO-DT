# %%
import pandas as pd

# %%
df = pd.read_csv("ground_20.csv")

# %%
df.describe()
# Out:
#             current       voltage   temperature         power          time
# count  32796.000000  32796.000000  32796.000000  32796.000000  32796.000000
# mean       0.004490      3.782461    296.826164      0.489138  17461.892243
# std        7.980049      0.225685      0.640414     29.437977   9745.023694
# min      -20.022500      2.999900    295.663000    -81.387636      0.000000
# 25%        0.000000      3.617075    296.345500      0.000000   9446.750000
# 50%        0.000000      3.746800    296.719150      0.000000  17645.500000
# 75%        0.768800      3.947525    297.201000      3.190344  25844.250000
# max       10.011000      4.150200    299.595100     41.482760  34043.000000

# %%
df['voltage'].plot()
# Out:
# <Axes: >

# %%
df['temperature'].plot()
# Out:
# <Axes: >

# %%
df['current'].plot()
# Out:
# <Axes: >
