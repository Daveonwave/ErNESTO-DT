# %%
import pandas as pd
from sklearn.preprocessing import MinMaxScaler
from notebooks.online_learning.utils import plotting_utils

# %% [markdown]
# Take the case of phi_0, the idea is to compare the starting cluster with the final and also the outliers and anomalies

# %%
phi_0_df_new = pd.read_csv('../../data/output/final_experiment/no_gaussianity_trial/phi_0.csv')
phi_0_df_starting = pd.read_csv('../../data/ground/nominal_cluster/phi_one.csv')
phi_0_history_theta_df = pd.read_csv('../../data/output/final_experiment/no_gaussianity_trial/phi_0_history_theta.csv')
phi_0_outliers_df = pd.read_csv('../../data/output/final_experiment/no_gaussianity_trial/phi_0_outliers_sets.csv')

# %%
phi_0_df_starting.head()
# Out:
#    Temp  Soc           C_1       R_0       R_1  OCV
# 0    15    0   9362.838793  0.016177  0.016432  NaN
# 1    15   10   9691.182929  0.016623  0.019499  NaN
# 2    15   20  12052.351794  0.017420  0.023310  NaN
# 3    15   30   9306.629723  0.018662  0.024055  NaN
# 4    15   40   5139.236488  0.024588  0.035098  NaN

# %%
phi_0_df_starting = phi_0_df_starting.rename(columns={'C_1':'c', 'R_1':'rc', 'R_0':'r0'})
phi_0_df_starting = phi_0_df_starting.drop(columns=['Temp','Soc','OCV'], axis=1)

# %%
scaler = MinMaxScaler()
phi_0_df_starting_scaled = pd.DataFrame(scaler.fit_transform(phi_0_df_starting), columns=phi_0_df_starting.columns)

# %%
phi_0_df_starting_scaled.describe()
# Out:
#                c         r0         rc
# count  60.000000  60.000000  60.000000
# mean    0.600092   0.191687   0.131705
# std     0.267691   0.199752   0.220170
# min     0.000000   0.000000   0.000000
# 25%     0.449437   0.030443   0.027283
# 50%     0.684058   0.136526   0.055621
# 75%     0.764405   0.285776   0.119217
# max     1.000000   1.000000   1.000000

# %%
plotting_utils.threed_scatter(phi_0_df_starting_scaled)

# %% [markdown]
# ## PHI_1

# %%
phi_1_df_new = pd.read_csv('../../data/output/final_experiment/no_gaussianity_trial/phi_1.csv')
phi_1_df_starting = pd.read_csv('../../data/ground/nominal_cluster/phi_two.csv')
phi_1_history_theta_df = pd.read_csv('../../data/output/final_experiment/no_gaussianity_trial/phi_1_history_theta.csv')
phi_1_outliers_df = pd.read_csv('../../data/output/final_experiment/no_gaussianity_trial/phi_1_outliers_sets.csv')

# %%
phi_1_df_starting.describe()
# Out:
#             Temp         Soc           C_1        R_0        R_1        OCV
# count  60.000000   60.000000     60.000000  60.000000  60.000000  48.000000
# mean   19.000000   75.000000  10898.610389   0.013090   0.015514  27.219542
# std     6.689227   17.222374   3296.695650   0.003160   0.004286   0.973577
# min    10.000000   50.000000   6329.622654   0.009210   0.009238  25.827000
# 25%    10.000000   60.000000   8070.132353   0.010474   0.011761  26.251750
# 50%    22.500000   75.000000  10351.731264   0.011748   0.014324  27.262500
# 75%    25.000000   90.000000  13357.329312   0.015858   0.018259  28.226250
# max    25.000000  100.000000  19489.447086   0.019599   0.027384  28.504571

# %%
phi_1_df_starting = phi_1_df_starting.rename(columns={'C_1':'c', 'R_1':'rc', 'R_0':'r0'})
phi_1_df_starting = phi_1_df_starting.drop(columns=['Temp','Soc','OCV'], axis=1)

# %%
scaler = MinMaxScaler()
phi_1_df_starting_scaled = pd.DataFrame(scaler.fit_transform(phi_1_df_starting), columns=phi_1_df_starting.columns)

# %%
plotting_utils.threed_scatter(phi_1_df_starting_scaled)

# %% [markdown]
# ## PHI_2

# %%
phi_2_df_new = pd.read_csv('../../data/output/final_experiment/no_gaussianity_trial/phi_2.csv')
phi_2_df_starting = pd.read_csv('../../data/ground/nominal_cluster/phi_three.csv')
phi_2_history_theta_df = pd.read_csv('../../data/output/final_experiment/no_gaussianity_trial/phi_2_history_theta.csv')
phi_2_outliers_df = pd.read_csv('../../data/output/final_experiment/no_gaussianity_trial/phi_2_outliers_sets.csv')

# %%
phi_2_df_starting.describe()
# Out:
#             Temp        Soc           C_1        R_0        R_1        OCV
# count  30.000000  30.000000     30.000000  30.000000  30.000000  18.000000
# mean   37.000000  25.000000  18425.512585   0.009181   0.012408  25.155389
# std     4.068381  17.370208   7048.486765   0.001296   0.004151   0.600765
# min    30.000000   0.000000  10131.783114   0.007695   0.008126  24.170000
# 25%    35.000000  10.000000  14407.880252   0.008148   0.009793  24.671500
# 50%    40.000000  25.000000  16104.007602   0.008831   0.011397  25.250500
# 75%    40.000000  40.000000  20333.787444   0.009916   0.013337  25.651250
# max    40.000000  50.000000  41591.069006   0.013400   0.026787  25.920000

# %%
phi_2_df_starting = phi_2_df_starting.rename(columns={'C_1':'c', 'R_1':'rc', 'R_0':'r0'})
phi_2_df_starting = phi_2_df_starting.drop(columns=['Temp','Soc','OCV'], axis=1)

# %%
scaler = MinMaxScaler()
phi_2_df_starting_scaled = pd.DataFrame(scaler.fit_transform(phi_2_df_starting), columns=phi_2_df_starting.columns)

# %%
plotting_utils.threed_scatter(phi_2_df_starting_scaled)

# %% [markdown]
# ## PHI_3

# %%
phi_3_df_new = pd.read_csv('../../data/output/final_experiment/no_gaussianity_trial/phi_3.csv')
phi_3_df_starting = pd.read_csv('../../data/ground/nominal_cluster/phi_four.csv')
phi_3_history_theta_df = pd.read_csv('../../data/output/final_experiment/no_gaussianity_trial/phi_3_history_theta.csv')
phi_3_outliers_df = pd.read_csv('../../data/output/final_experiment/no_gaussianity_trial/phi_3_outliers_sets.csv')

# %%
phi_3_df_starting.describe()
# Out:
#             Temp         Soc           C_1        R_0        R_1        OCV
# count  30.000000   30.000000     30.000000  30.000000  30.000000  18.000000
# mean   37.000000   75.000000  15440.923761   0.008263   0.009985  27.258873
# std     4.068381   17.370208   3434.621295   0.000749   0.002308   0.983160
# min    30.000000   50.000000  10370.463310   0.007287   0.006666  25.896000
# 25%    35.000000   60.000000  13181.629919   0.007684   0.008439  26.311750
# 50%    40.000000   75.000000  14441.721726   0.008014   0.009394  27.286000
# 75%    40.000000   90.000000  16717.108214   0.008814   0.010862  28.258500
# max    40.000000  100.000000  27306.615043   0.009951   0.016169  28.517429

# %%
phi_3_df_starting = phi_3_df_starting.rename(columns={'C_1':'c', 'R_1':'rc', 'R_0':'r0'})
phi_3_df_starting = phi_3_df_starting.drop(columns=['Temp','Soc','OCV'], axis=1)

# %%
scaler = MinMaxScaler()
phi_3_df_starting_scaled = pd.DataFrame(scaler.fit_transform(phi_3_df_starting), columns=phi_3_df_starting.columns)

# %%
plotting_utils.threed_scatter(phi_3_df_starting_scaled)
