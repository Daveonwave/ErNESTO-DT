# %%
# %load_ext autoreload
# %autoreload 2
# %matplotlib inline
# %cd ../..
# Out:
# /Users/dave/Library/CloudStorage/OneDrive-PolitecnicodiMilano/PhD/Repositories/DT-rse

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import os

from ernesto.postprocessing.visualization import ernesto_plotter
from ernesto.postprocessing.metrics import compute_metrics, _mse

# %%
df_data = pd.read_csv("data/external/validationOL/C1_5_Cluster_OL.csv")

# %%
df_data
# Out:
#         Time [s]  Voltage [V]  Current [A]  Cell Temperature [degC]  \
# 0            1.0      3.89722     -19.9866                  40.1424
# 1            2.0      3.89431     -19.9778                  40.2251
# 2            3.0      3.89243     -19.9778                  40.1489
# 3            4.0      3.89085     -19.9778                  40.1000
# 4            5.0      3.88942     -19.9778                  40.1380
# ...          ...          ...          ...                      ...
# 899995    1083.0      3.46474     -19.9786                  13.3473
# 899996    1084.0      3.46462     -19.9786                  13.2417
# 899997    1085.0      3.46451     -19.9786                  13.2552
# 899998    1086.0      3.46438     -19.9786                  13.3043
# 899999    1087.0      3.46427     -19.9786                  13.3324
#
#         Ambient Temperature [degC]
# 0                          40.0603
# 1                          40.0158
# 2                          40.0078
# 3                          40.0403
# 4                          40.0331
# ...                            ...
# 899995                     10.5194
# 899996                     10.5242
# 899997                     10.4918
# 899998                     10.5105
# 899999                     10.5478
#
# [900000 rows x 5 columns]

# %%
df_data['Time [s]'][:100000].plot()
# Out:
# <Axes: >

# %%
df_data['Current [A]'][:4000].plot()
# Out:
# <Axes: >

# %%
df_data['Time'] = range(len(df_data))
df_data['Ambient Temperature [K]'] = df_data['Ambient Temperature [degC]'] + 273.15
df_data['Cell Temperature [K]'] = df_data['Cell Temperature [degC]'] + 273.15

# %%
df_data = df_data.drop(columns=['Time [s]', 'Ambient Temperature [degC]', 'Cell Temperature [degC]'])

# %%
df_data
# Out:
#         Voltage [V]  Current [A]    Time  Ambient Temperature [K]  \
# 0           3.89722     -19.9866       0                 313.2103
# 1           3.89431     -19.9778       1                 313.1658
# 2           3.89243     -19.9778       2                 313.1578
# 3           3.89085     -19.9778       3                 313.1903
# 4           3.88942     -19.9778       4                 313.1831
# ...             ...          ...     ...                      ...
# 899995      3.46474     -19.9786  899995                 283.6694
# 899996      3.46462     -19.9786  899996                 283.6742
# 899997      3.46451     -19.9786  899997                 283.6418
# 899998      3.46438     -19.9786  899998                 283.6605
# 899999      3.46427     -19.9786  899999                 283.6978
#
#         Cell Temperature [K]
# 0                   313.2924
# 1                   313.3751
# 2                   313.2989
# 3                   313.2500
# 4                   313.2880
# ...                      ...
# 899995              286.4973
# 899996              286.3917
# 899997              286.4052
# 899998              286.4543
# 899999              286.4824
#
# [900000 rows x 5 columns]

# %%
df_data.to_csv("data/ground/online_learning/region_shift_validation.csv", index=False)

# %%
# SOTTO ROBA DI ALTRO ESPERIMENTO COME TEMPLATE

# %%
df_t_amb = df_t_amb[['TEST TIME', 'DWell Time(ms)', 'T6a']]

# %%
df_t_amb
# Out:
#                   TEST TIME  DWell Time(ms)      T6a
# 0       2024/10/28 16:01:51              10  21.3768
# 1       2024/10/28 16:01:52            1010  21.3631
# 2       2024/10/28 16:01:53            2010  21.3664
# 3       2024/10/28 16:01:54            3010  21.2692
# 4       2024/10/28 16:01:55            4010  21.3226
# ...                     ...             ...      ...
# 149298  2024/10/30 09:30:09       149298010  20.9004
# 149299  2024/10/30 09:30:10       149299010  20.8092
# 149300  2024/10/30 09:30:11       149300010  20.8517
# 149301  2024/10/30 09:30:12       149301010  20.7950
# 149302  2024/10/30 09:30:12       149301140  20.7950
#
# [149303 rows x 3 columns]

# %%
# Allineo T_amb e dataset perché il dataset inizia prima di t_amb
df_data[df_data['TEST TIME'] == df_t_amb['TEST TIME'][0]]
# Out:
#               TEST TIME  DWell Time(ms)  Voltage(V)  Current(A)  Capacity(Ah)  \
# 17  2024/10/28 16:01:51           17010       3.715     10.0152        0.0473
#
#     Total Capacity(Ah)   Power(W)       KWh      T2a
# 17              0.0473  37.206279  0.000176  21.2097

# %%
df_data.iloc[15:19]
# Out:
#               TEST TIME  DWell Time(ms)  Voltage(V)  Current(A)  Capacity(Ah)  \
# 15  2024/10/28 16:01:49           15010      3.7140     10.0197        0.0418
# 16  2024/10/28 16:01:50           16010      3.7145     10.0158        0.0446
# 17  2024/10/28 16:01:51           17010      3.7150     10.0152        0.0473
# 18  2024/10/28 16:01:52           18010      3.7155     10.0161        0.0501
#
#     Total Capacity(Ah)   Power(W)       KWh      T2a
# 15              0.0418  37.212921  0.000155  21.2492
# 16              0.0446  37.204251  0.000165  21.1974
# 17              0.0473  37.206279  0.000176  21.2097
# 18              0.0501  37.214712  0.000186  21.2296

# %%
df_data['DWell Time(ms)'] = df_data['DWell Time(ms)'] - 17000
df_data = df_data[17:]

# %%
df_data
# Out:
#                  TEST TIME  DWell Time(ms)  Voltage(V)  Current(A)  \
# 17     2024/10/28 16:01:51              10      3.7150     10.0152
# 18     2024/10/28 16:01:52            1010      3.7155     10.0161
# 19     2024/10/28 16:01:53            2010      3.7161     10.0220
# 20     2024/10/28 16:01:54            3010      3.7165     10.0172
# 21     2024/10/28 16:01:55            4010      3.7170     10.0165
# ...                    ...             ...         ...         ...
# 90493  2024/10/29 17:09:45        90473860      3.9943      0.3129
# 90494  2024/10/29 17:09:46        90474860      3.9943      0.3038
# 90495  2024/10/29 17:09:47        90475860      3.9940      0.3242
# 90496  2024/10/29 17:09:48        90476860      3.9940      0.3151
# 90497  2024/10/29 17:09:49        90477860      3.9944      0.3106
#
#        Capacity(Ah)  Total Capacity(Ah)   Power(W)       KWh      T2a
# 17           0.0473              0.0473  37.206279  0.000176  21.2097
# 18           0.0501              0.0501  37.214712  0.000186  21.2296
# 19           0.0529              0.0529  37.242262  0.000196  21.1824
# 20           0.0557              0.0557  37.228419  0.000207  21.1700
# 21           0.0585              0.0585  37.231728  0.000217  21.2103
# ...             ...                 ...        ...       ...      ...
# 90493        2.1019              9.4572   1.249620  0.008336  21.6960
# 90494        2.1020              9.4573   1.213399  0.008337  21.6748
# 90495        2.1021              9.4574   1.294813  0.008337  21.6812
# 90496        2.1022              9.4575   1.258595  0.008337  21.6546
# 90497        2.1023              9.4576   1.240605  0.008338  21.7193
#
# [90481 rows x 9 columns]

# %%
df_t_amb.tail()
# Out:
#                   TEST TIME  DWell Time(ms)      T6a
# 149298  2024/10/30 09:30:09       149298010  20.9004
# 149299  2024/10/30 09:30:10       149299010  20.8092
# 149300  2024/10/30 09:30:11       149300010  20.8517
# 149301  2024/10/30 09:30:12       149301010  20.7950
# 149302  2024/10/30 09:30:12       149301140  20.7950

# %%
df_data.tail()
# Out:
#                  TEST TIME  DWell Time(ms)  Voltage(V)  Current(A)  \
# 90493  2024/10/29 17:09:45        90473860      3.9943      0.3129
# 90494  2024/10/29 17:09:46        90474860      3.9943      0.3038
# 90495  2024/10/29 17:09:47        90475860      3.9940      0.3242
# 90496  2024/10/29 17:09:48        90476860      3.9940      0.3151
# 90497  2024/10/29 17:09:49        90477860      3.9944      0.3106
#
#        Capacity(Ah)  Total Capacity(Ah)  Power(W)       KWh      T2a
# 90493        2.1019              9.4572  1.249620  0.008336  21.6960
# 90494        2.1020              9.4573  1.213399  0.008337  21.6748
# 90495        2.1021              9.4574  1.294813  0.008337  21.6812
# 90496        2.1022              9.4575  1.258595  0.008337  21.6546
# 90497        2.1023              9.4576  1.240605  0.008338  21.7193

# %%
signal_len = 1000 #len(df_data)

plt.plot(range(0, signal_len), df_data['DWell Time(ms)'][:signal_len], label='data')
plt.plot(range(0, signal_len), df_t_amb['DWell Time(ms)'][:signal_len], label='t_amb')
plt.legend()

# %%
dt_data = [t2 - t1 for t2,t1 in zip(df_data['DWell Time(ms)'][1:], df_data['DWell Time(ms)'])]

# %%
dt_t_amb = [t2 - t1 for t2,t1 in zip(df_t_amb['DWell Time(ms)'][1:], df_t_amb['DWell Time(ms)'])]

# %%
df_data[df_data.duplicated(['TEST TIME'])]
# Out:
#                 TEST TIME  DWell Time(ms)  Voltage(V)  Current(A)  \
# 4259  2024/10/28 17:12:32         4241850      3.8997      0.1995
# 4560  2024/10/28 17:17:32         4541850      3.8970      0.0000
#
#       Capacity(Ah)  Total Capacity(Ah)  Power(W)       KWh      T2a
# 4259        7.3553              7.3553  0.777991  0.028104  22.3035
# 4560        0.0000              7.3553  0.000000  0.000000  22.2183

# %%
df_data.loc[4257:4261]
# Out:
#                 TEST TIME  DWell Time(ms)  Voltage(V)  Current(A)  \
# 4257  2024/10/28 17:12:31         4240010      3.8999      0.2911
# 4258  2024/10/28 17:12:32         4241010      3.8998      0.2723
# 4259  2024/10/28 17:12:32         4241850      3.8997      0.1995
# 4260  2024/10/28 17:12:33         4241860      3.8988      0.0000
# 4261  2024/10/28 17:12:34         4242860      3.8988      0.0000
#
#       Capacity(Ah)  Total Capacity(Ah)  Power(W)       KWh      T2a
# 4257        7.3551              7.3551  1.135234  0.028103  22.2123
# 4258        7.3552              7.3552  1.061819  0.028104  22.2678
# 4259        7.3553              7.3553  0.777991  0.028104  22.3035
# 4260        0.0000              7.3553  0.000000  0.000000  22.3035
# 4261        0.0000              7.3553  0.000000  0.000000  22.2447

# %%
df_data.loc[4558:4563]
# Out:
#                 TEST TIME  DWell Time(ms)  Voltage(V)  Current(A)  \
# 4558  2024/10/28 17:17:31         4539860      3.8972      0.0000
# 4559  2024/10/28 17:17:32         4540860      3.8971      0.0000
# 4560  2024/10/28 17:17:32         4541850      3.8970      0.0000
# 4561  2024/10/28 17:17:33         4541860      3.8969      0.0272
# 4562  2024/10/28 17:17:34         4542860      3.8970      0.0249
# 4563  2024/10/28 17:17:35         4543860      3.8976      0.0159
#
#       Capacity(Ah)  Total Capacity(Ah)  Power(W)           KWh      T2a
# 4558           0.0              7.3553  0.000000  0.000000e+00  22.2582
# 4559           0.0              7.3553  0.000000  0.000000e+00  22.2009
# 4560           0.0              7.3553  0.000000  0.000000e+00  22.2183
# 4561           0.0              7.3553  0.106013  0.000000e+00  22.2076
# 4562           0.0              7.3553  0.097182  0.000000e+00  22.1582
# 4563           0.0              7.3553  0.061853  1.000000e-07  22.2501

# %%
# Rimuovo indici con DWell Time sfalsato
df_data = df_data.drop(index=[idx for idx in df_data[df_data.duplicated(['TEST TIME'])].index], axis=0)

# %%
dt_data = [t2 - t1 for t2,t1 in zip(df_data['DWell Time(ms)'][1:], df_data['DWell Time(ms)'])]

# %%
plt.plot(dt_data[4240:4245])

# %%
df_data[4240:4245]
# Out:
#                 TEST TIME  DWell Time(ms)  Voltage(V)  Current(A)  \
# 4257  2024/10/28 17:12:31         4240010      3.8999      0.2911
# 4258  2024/10/28 17:12:32         4241010      3.8998      0.2723
# 4260  2024/10/28 17:12:33         4241860      3.8988      0.0000
# 4261  2024/10/28 17:12:34         4242860      3.8988      0.0000
# 4262  2024/10/28 17:12:35         4243860      3.8987      0.0000
#
#       Capacity(Ah)  Total Capacity(Ah)  Power(W)       KWh      T2a
# 4257        7.3551              7.3551  1.135234  0.028103  22.2123
# 4258        7.3552              7.3552  1.061819  0.028104  22.2678
# 4260        0.0000              7.3553  0.000000  0.000000  22.3035
# 4261        0.0000              7.3553  0.000000  0.000000  22.2447
# 4262        0.0000              7.3553  0.000000  0.000000  22.2945

# %%
df_t_amb[df_t_amb.duplicated(['TEST TIME'])]
# Out:
#                   TEST TIME  DWell Time(ms)     T6a
# 149302  2024/10/30 09:30:12       149301140  20.795

# %%
df_t_amb[df_t_amb['TEST TIME'] == df_data['TEST TIME'].iloc[-1]]
# Out:
#                  TEST TIME  DWell Time(ms)      T6a
# 90478  2024/10/29 17:09:49        90478010  21.3947

# %%
df_t_amb.iloc[149300:149305]
# Out:
#                   TEST TIME  DWell Time(ms)      T6a
# 149300  2024/10/30 09:30:11       149300010  20.8517
# 149301  2024/10/30 09:30:12       149301010  20.7950
# 149302  2024/10/30 09:30:12       149301140  20.7950

# %%
df_t_amb_fixed = df_t_amb[:90479]

# %%
df_t_amb_fixed
# Out:
#                  TEST TIME  DWell Time(ms)      T6a
# 0      2024/10/28 16:01:51              10  21.3768
# 1      2024/10/28 16:01:52            1010  21.3631
# 2      2024/10/28 16:01:53            2010  21.3664
# 3      2024/10/28 16:01:54            3010  21.2692
# 4      2024/10/28 16:01:55            4010  21.3226
# ...                    ...             ...      ...
# 90474  2024/10/29 17:09:45        90474010  21.3257
# 90475  2024/10/29 17:09:46        90475010  21.3367
# 90476  2024/10/29 17:09:47        90476010  21.3182
# 90477  2024/10/29 17:09:48        90477010  21.3192
# 90478  2024/10/29 17:09:49        90478010  21.3947
#
# [90479 rows x 3 columns]

# %%
df_data
# Out:
#                  TEST TIME  DWell Time(ms)  Voltage(V)  Current(A)  \
# 17     2024/10/28 16:01:51              10      3.7150     10.0152
# 18     2024/10/28 16:01:52            1010      3.7155     10.0161
# 19     2024/10/28 16:01:53            2010      3.7161     10.0220
# 20     2024/10/28 16:01:54            3010      3.7165     10.0172
# 21     2024/10/28 16:01:55            4010      3.7170     10.0165
# ...                    ...             ...         ...         ...
# 90493  2024/10/29 17:09:45        90473860      3.9943      0.3129
# 90494  2024/10/29 17:09:46        90474860      3.9943      0.3038
# 90495  2024/10/29 17:09:47        90475860      3.9940      0.3242
# 90496  2024/10/29 17:09:48        90476860      3.9940      0.3151
# 90497  2024/10/29 17:09:49        90477860      3.9944      0.3106
#
#        Capacity(Ah)  Total Capacity(Ah)   Power(W)       KWh      T2a
# 17           0.0473              0.0473  37.206279  0.000176  21.2097
# 18           0.0501              0.0501  37.214712  0.000186  21.2296
# 19           0.0529              0.0529  37.242262  0.000196  21.1824
# 20           0.0557              0.0557  37.228419  0.000207  21.1700
# 21           0.0585              0.0585  37.231728  0.000217  21.2103
# ...             ...                 ...        ...       ...      ...
# 90493        2.1019              9.4572   1.249620  0.008336  21.6960
# 90494        2.1020              9.4573   1.213399  0.008337  21.6748
# 90495        2.1021              9.4574   1.294813  0.008337  21.6812
# 90496        2.1022              9.4575   1.258595  0.008337  21.6546
# 90497        2.1023              9.4576   1.240605  0.008338  21.7193
#
# [90479 rows x 9 columns]

# %%
df_res = df_data.merge(df_t_amb_fixed, on='TEST TIME')

# %%
df_res = df_res.rename(columns={'T2a': 'Temp(degC)', 'T6a': 'T_amb', 'TEST TIME':'Time'})

# %%
df_res
# Out:
#                       Time  DWell Time(ms)_x  Voltage(V)  Current(A)  \
# 0      2024/10/28 16:01:51                10      3.7150     10.0152
# 1      2024/10/28 16:01:52              1010      3.7155     10.0161
# 2      2024/10/28 16:01:53              2010      3.7161     10.0220
# 3      2024/10/28 16:01:54              3010      3.7165     10.0172
# 4      2024/10/28 16:01:55              4010      3.7170     10.0165
# ...                    ...               ...         ...         ...
# 90474  2024/10/29 17:09:45          90473860      3.9943      0.3129
# 90475  2024/10/29 17:09:46          90474860      3.9943      0.3038
# 90476  2024/10/29 17:09:47          90475860      3.9940      0.3242
# 90477  2024/10/29 17:09:48          90476860      3.9940      0.3151
# 90478  2024/10/29 17:09:49          90477860      3.9944      0.3106
#
#        Capacity(Ah)  Total Capacity(Ah)   Power(W)       KWh  Temp(degC)  \
# 0            0.0473              0.0473  37.206279  0.000176     21.2097
# 1            0.0501              0.0501  37.214712  0.000186     21.2296
# 2            0.0529              0.0529  37.242262  0.000196     21.1824
# 3            0.0557              0.0557  37.228419  0.000207     21.1700
# 4            0.0585              0.0585  37.231728  0.000217     21.2103
# ...             ...                 ...        ...       ...         ...
# 90474        2.1019              9.4572   1.249620  0.008336     21.6960
# 90475        2.1020              9.4573   1.213399  0.008337     21.6748
# 90476        2.1021              9.4574   1.294813  0.008337     21.6812
# 90477        2.1022              9.4575   1.258595  0.008337     21.6546
# 90478        2.1023              9.4576   1.240605  0.008338     21.7193
#
#        DWell Time(ms)_y    T_amb
# 0                    10  21.3768
# 1                  1010  21.3631
# 2                  2010  21.3664
# 3                  3010  21.2692
# 4                  4010  21.3226
# ...                 ...      ...
# 90474          90474010  21.3257
# 90475          90475010  21.3367
# 90476          90476010  21.3182
# 90477          90477010  21.3192
# 90478          90478010  21.3947
#
# [90479 rows x 11 columns]

# %%
df_res.to_csv("../../data/ground/paper_dic24/test_facility.csv", index=False)

# %%
df_res['Voltage(V)'].plot()
# Out:
# <Axes: >

# %%
max(df_res['Voltage(V)'])
# Out:
# 3.9948

# %%
import pandas as pd

# %%
df = pd.read_csv("../../data/ground/paper_dic24/test_facility.csv")

# %%
df['T_amb'] += 0.25

# %%
df
# Out:
#                       Time  DWell Time(ms)_x  Voltage(V)  Current(A)  \
# 0      2024/10/28 16:01:51                10      3.7150     10.0152
# 1      2024/10/28 16:01:52              1010      3.7155     10.0161
# 2      2024/10/28 16:01:53              2010      3.7161     10.0220
# 3      2024/10/28 16:01:54              3010      3.7165     10.0172
# 4      2024/10/28 16:01:55              4010      3.7170     10.0165
# ...                    ...               ...         ...         ...
# 90474  2024/10/29 17:09:45          90473860      3.9943      0.3129
# 90475  2024/10/29 17:09:46          90474860      3.9943      0.3038
# 90476  2024/10/29 17:09:47          90475860      3.9940      0.3242
# 90477  2024/10/29 17:09:48          90476860      3.9940      0.3151
# 90478  2024/10/29 17:09:49          90477860      3.9944      0.3106
#
#        Capacity(Ah)  Total Capacity(Ah)   Power(W)       KWh  Temp(degC)  \
# 0            0.0473              0.0473  37.206279  0.000176     21.2097
# 1            0.0501              0.0501  37.214712  0.000186     21.2296
# 2            0.0529              0.0529  37.242262  0.000196     21.1824
# 3            0.0557              0.0557  37.228419  0.000207     21.1700
# 4            0.0585              0.0585  37.231728  0.000217     21.2103
# ...             ...                 ...        ...       ...         ...
# 90474        2.1019              9.4572   1.249620  0.008336     21.6960
# 90475        2.1020              9.4573   1.213399  0.008337     21.6748
# 90476        2.1021              9.4574   1.294813  0.008337     21.6812
# 90477        2.1022              9.4575   1.258595  0.008337     21.6546
# 90478        2.1023              9.4576   1.240605  0.008338     21.7193
#
#        DWell Time(ms)_y    T_amb
# 0                    10  21.6268
# 1                  1010  21.6131
# 2                  2010  21.6164
# 3                  3010  21.5192
# 4                  4010  21.5726
# ...                 ...      ...
# 90474          90474010  21.5757
# 90475          90475010  21.5867
# 90476          90476010  21.5682
# 90477          90477010  21.5692
# 90478          90478010  21.6447
#
# [90479 rows x 11 columns]

# %%
df.to_csv("../../data/ground/paper_dic24/prova_normale_with_Tamb_offset.csv", index=False)
