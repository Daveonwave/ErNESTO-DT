# %%
import pandas as pd
import matplotlib.pyplot as plt
from scipy.interpolate import interp1d

# %% [markdown]
# ![immagine.png](attachment:immagine.png)

# %%
soc = [0.9, 0.8,0.7, 0.6, 0.5, 0.4, 0.3, 0.2, 0.1, 0]
r0 = [0.003750375, 0.003750375, 0.003750188, 0.00380057, 0.003900585, 0.003950593, 0.004050203, 0.004050405, 0.004150208, 0.004250213]
ocv = [4.033, 3.938, 3.854, 3.762, 3.703, 3.668, 3.641, 3.599, 3.54, 3.492]
r1 = [0.002905235, 0.002905235, 0.003274787, 0.003529802, 0.002902704, 0.00288569, 0.003301184, 0.003828509, 0.00401881, 0.005274097]
tau = [44.49723035, 44.49723035, 62.49298402, 95.71242746, 54.55035884, 51.96821295, 66.78471632, 86.65639491, 69.03646918, 37.70846003]
c1 = [15316.22569, 15316.22569, 19083.06683, 27115.52179, 18792.94594, 18008.9387, 20230.53144, 22634.50022, 17178.33758, 7149.747094]

# %%
plt.plot(soc, c1)

# %%
plt.plot(soc, ocv)

# %%
x_interp = 0.55
y_interp = interp1d(soc, r0)
print(x_interp, y_interp(x_interp))
# Out:
# 0.55 0.0038505774999999997
