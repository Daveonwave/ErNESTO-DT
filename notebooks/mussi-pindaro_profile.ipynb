# %%
import pandas as pd

# %%
df = pd.read_csv("../data/external/mussi_pindaro/PV_1year/camporosso_2.csv")

# %%
df
# Out:
#       Unnamed: 0              Date  Power  Air
# 0              0  01/01/2017 00:00    0.0  0.0
# 1              1  01/01/2017 01:00    0.0  0.0
# 2              2  01/01/2017 02:00    0.0  0.0
# 3              3  01/01/2017 03:00    0.0  0.0
# 4              4  01/01/2017 04:00    0.0  0.0
# ...          ...               ...    ...  ...
# 8755        8755  31/12/2017 19:00    0.0  0.0
# 8756        8756  31/12/2017 20:00    0.0  0.0
# 8757        8757  31/12/2017 21:00    0.0  0.0
# 8758        8758  31/12/2017 22:00    0.0  0.0
# 8759        8759  31/12/2017 23:00    0.0  0.0
#
# [8760 rows x 4 columns]

# %%
df['Power'].plot()
# Out:
# <Axes: >

# %%
df_load = pd.read_csv("../data/external/mussi_pindaro/load/Carico.csv")

# %%
df_load.plot()
# Out:
# <Axes: >
